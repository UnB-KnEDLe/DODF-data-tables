# %% [markdown]
# ## Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.pyplot import figure
pd.set_option("display.max_rows", None, "display.max_columns", None)
#jupyter nbconvert my_notebook.ipynb --to html --output output.html

# %%
from IPython.display import HTML
import random

def hide_toggle(for_next=False):
    this_cell = """$('div.cell.code_cell.rendered.selected')"""
    next_cell = this_cell + '.next()'

    toggle_text = 'Toggle show/hide'  # text shown on toggle link
    target_cell = this_cell  # target cell to control with toggle
    js_hide_current = ''  # bit of JS to permanently hide code in current cell (only when toggling next cell)

    if for_next:
        target_cell = next_cell
        toggle_text += ' next cell'
        js_hide_current = this_cell + '.find("div.input").hide();'

    js_f_name = 'code_toggle_{}'.format(str(random.randint(1,2**64)))

    html = """
        <script>
            function {f_name}() {{
                {cell_selector}.find('div.input').toggle();
            }}

            {js_hide_current}
        </script>

        <a href="javascript:{f_name}()">{toggle_text}</a>
    """.format(
        f_name=js_f_name,
        cell_selector=target_cell,
        js_hide_current=js_hide_current, 
        toggle_text=toggle_text
    )

    return HTML(html)

hide_toggle()
# Out:
#         <script>
#             function code_toggle_7654500638302595288() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_7654500638302595288()">Toggle show/hide</a>

# %% [markdown]
# ## Tabela Informações Básicas

# %%
basic = ["Numero do DODF", "Data do DODF", "Páginas da piblicação", "Seção", "Tópico"]
basic_table = {"Informações Básicas": basic}
basic_table = pd.DataFrame(basic_table).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
basic_table
hide_toggle()
# Out:
#         <script>
#             function code_toggle_9344473580519194982() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_9344473580519194982()">Toggle show/hide</a>

# %%
basic_table
# Out:
# <style  type="text/css" >
#     #T_6b48a6a6_9ae6_11ea_85b8_1c3e84d81555 th {
#           text-align: left;
#     }    #T_6b48a6a6_9ae6_11ea_85b8_1c3e84d81555row0_col0 {
#             text-align:  left;
#         }    #T_6b48a6a6_9ae6_11ea_85b8_1c3e84d81555row1_col0 {
#             text-align:  left;
#         }    #T_6b48a6a6_9ae6_11ea_85b8_1c3e84d81555row2_col0 {
#             text-align:  left;
#         }    #T_6b48a6a6_9ae6_11ea_85b8_1c3e84d81555row3_col0 {
#             text-align:  left;
#         }    #T_6b48a6a6_9ae6_11ea_85b8_1c3e84d81555row4_col0 {
#             text-align:  left;
#         }</style><table id="T_6b48a6a6_9ae6_11ea_85b8_1c3e84d81555" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Informações Básicas</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6b48a6a6_9ae6_11ea_85b8_1c3e84d81555level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %% [markdown]
# ## Tabela Atos

# %%
atos = pd.read_csv('./data/CSVs/atos.csv')
atos = pd.DataFrame(atos).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
hide_toggle()
# Out:
#         <script>
#             function code_toggle_15659396354776653652() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_15659396354776653652()">Toggle show/hide</a>

# %%
atos
# Out:
# <style  type="text/css" >
#     #T_6b5396f6_9ae6_11ea_85b8_1c3e84d81555 th {
#           text-align: left;
#     }    #T_6b5396f6_9ae6_11ea_85b8_1c3e84d81555row0_col0 {
#             text-align:  left;
#         }    #T_6b5396f6_9ae6_11ea_85b8_1c3e84d81555row0_col1 {
#             text-align:  left;
#         }    #T_6b5396f6_9ae6_11ea_85b8_1c3e84d81555row0_col2 {
#             text-align:  left;
#         }    #T_6b5396f6_9ae6_11ea_85b8_1c3e84d81555row0_col3 {
#             text-align:  left;
#         }    #T_6b5396f6_9ae6_11ea_85b8_1c3e84d81555row1_col0 {
#             text-align:  left;
#         }    #T_6b5396f6_9ae6_11ea_85b8_1c3e84d81555row1_col1 {
#             text-align:  left;
#         }    #T_6b5396f6_9ae6_11ea_85b8_1c3e84d81555row1_col2 {
#             text-align:  left;
#         }    #T_6b5396f6_9ae6_11ea_85b8_1c3e84d81555row1_col3 {
#             text-align:  left;
#         }    #T_6b5396f6_9ae6_11ea_85b8_1c3e84d81555row2_col0 {
#             text-align:  left;
# ...

# %% [markdown]
# A coluna multiplo se refere ao contexto do Ato (não confundir com secretaria). Por exemplo o Ato de exoneração pode aparecer em contexto geral ou no contexto de cargos efetivos isso independente da secretaria em que o ato está.
#
# Essa multiplicidade aparece em decorrenência dos requisitos exigidos no documento gerado pelo TCDF, por exemplo o documento requisita como entrega o Ato "Retificações" no contexto de nomeação e exoneração e depois para aposentadorias. No geral é o mesmo Ato com as mesmas entidades porem podem existir pequenas diferenças padronizadas que serão usadas pra melhor distinguir seu contexto, portanto ao analisar um Ato multiplo é preciso especificar o contexto e correlacioná-los afim de se observar melhor padrões e diferenças

# %% [markdown]
# ## Aposentadoria

# %%
aposentadoria = pd.read_csv('./data/CSVs/aposentadoria.csv')
aposentadoria = pd.DataFrame(aposentadoria)
aposentadoria_layout = pd.DataFrame(aposentadoria).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
hide_toggle()
# Out:
#         <script>
#             function code_toggle_11948831784950560122() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_11948831784950560122()">Toggle show/hide</a>

# %%
aposentadoria_layout
# Out:
# <style  type="text/css" >
#     #T_6b5c708c_9ae6_11ea_85b8_1c3e84d81555 th {
#           text-align: left;
#     }    #T_6b5c708c_9ae6_11ea_85b8_1c3e84d81555row0_col0 {
#             text-align:  left;
#         }    #T_6b5c708c_9ae6_11ea_85b8_1c3e84d81555row0_col1 {
#             text-align:  left;
#         }    #T_6b5c708c_9ae6_11ea_85b8_1c3e84d81555row0_col2 {
#             text-align:  left;
#         }    #T_6b5c708c_9ae6_11ea_85b8_1c3e84d81555row1_col0 {
#             text-align:  left;
#         }    #T_6b5c708c_9ae6_11ea_85b8_1c3e84d81555row1_col1 {
#             text-align:  left;
#         }    #T_6b5c708c_9ae6_11ea_85b8_1c3e84d81555row1_col2 {
#             text-align:  left;
#         }    #T_6b5c708c_9ae6_11ea_85b8_1c3e84d81555row2_col0 {
#             text-align:  left;
#         }    #T_6b5c708c_9ae6_11ea_85b8_1c3e84d81555row2_col1 {
#             text-align:  left;
#         }    #T_6b5c708c_9ae6_11ea_85b8_1c3e84d81555row2_col2 {
#             text-align:  left;
# ...

# %% [markdown]
# ## Exonerações

# %%
exoneracao = pd.read_csv('./data/CSVs/exoneracao.csv')
exoneracao = pd.DataFrame(exoneracao)
exoneracao_layout = pd.DataFrame(exoneracao).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
hide_toggle()
# Out:
#         <script>
#             function code_toggle_3421570549069724648() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_3421570549069724648()">Toggle show/hide</a>

# %%
exoneracao_layout
# Out:
# <style  type="text/css" >
#     #T_6b66922e_9ae6_11ea_85b8_1c3e84d81555 th {
#           text-align: left;
#     }    #T_6b66922e_9ae6_11ea_85b8_1c3e84d81555row0_col0 {
#             text-align:  left;
#         }    #T_6b66922e_9ae6_11ea_85b8_1c3e84d81555row0_col1 {
#             text-align:  left;
#         }    #T_6b66922e_9ae6_11ea_85b8_1c3e84d81555row0_col2 {
#             text-align:  left;
#         }    #T_6b66922e_9ae6_11ea_85b8_1c3e84d81555row1_col0 {
#             text-align:  left;
#         }    #T_6b66922e_9ae6_11ea_85b8_1c3e84d81555row1_col1 {
#             text-align:  left;
#         }    #T_6b66922e_9ae6_11ea_85b8_1c3e84d81555row1_col2 {
#             text-align:  left;
#         }    #T_6b66922e_9ae6_11ea_85b8_1c3e84d81555row2_col0 {
#             text-align:  left;
#         }    #T_6b66922e_9ae6_11ea_85b8_1c3e84d81555row2_col1 {
#             text-align:  left;
#         }    #T_6b66922e_9ae6_11ea_85b8_1c3e84d81555row2_col2 {
#             text-align:  left;
# ...

# %% [markdown]
# ## Nomeação Cargos Comissionados

# %%
nomeacao_comissionados = pd.read_csv('./data/CSVs/nomeacao_comissionados.csv')
nomeacao_comissionados = pd.DataFrame(nomeacao_comissionados)
nomeacao_comissionados_layout = pd.DataFrame(nomeacao_comissionados).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
hide_toggle()
# Out:
#         <script>
#             function code_toggle_17190826532073234677() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_17190826532073234677()">Toggle show/hide</a>

# %%
nomeacao_comissionados_layout
# Out:
# <style  type="text/css" >
#     #T_6b6c54b6_9ae6_11ea_85b8_1c3e84d81555 th {
#           text-align: left;
#     }    #T_6b6c54b6_9ae6_11ea_85b8_1c3e84d81555row0_col0 {
#             text-align:  left;
#         }    #T_6b6c54b6_9ae6_11ea_85b8_1c3e84d81555row0_col1 {
#             text-align:  left;
#         }    #T_6b6c54b6_9ae6_11ea_85b8_1c3e84d81555row0_col2 {
#             text-align:  left;
#         }    #T_6b6c54b6_9ae6_11ea_85b8_1c3e84d81555row1_col0 {
#             text-align:  left;
#         }    #T_6b6c54b6_9ae6_11ea_85b8_1c3e84d81555row1_col1 {
#             text-align:  left;
#         }    #T_6b6c54b6_9ae6_11ea_85b8_1c3e84d81555row1_col2 {
#             text-align:  left;
#         }    #T_6b6c54b6_9ae6_11ea_85b8_1c3e84d81555row2_col0 {
#             text-align:  left;
#         }    #T_6b6c54b6_9ae6_11ea_85b8_1c3e84d81555row2_col1 {
#             text-align:  left;
#         }    #T_6b6c54b6_9ae6_11ea_85b8_1c3e84d81555row2_col2 {
#             text-align:  left;
# ...

# %% [markdown]
# ## Atos Sem Efeito

# %%
atos_sem_efeito = pd.read_csv('./data/CSVs/atos_sem_efeito.csv')
atos_sem_efeito = pd.DataFrame(atos_sem_efeito)
atos_sem_efeito_layout = pd.DataFrame(atos_sem_efeito).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
hide_toggle()
# Out:
#         <script>
#             function code_toggle_11279932902703167794() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_11279932902703167794()">Toggle show/hide</a>

# %%
atos_sem_efeito_layout
# Out:
# <style  type="text/css" >
#     #T_6b745db4_9ae6_11ea_85b8_1c3e84d81555 th {
#           text-align: left;
#     }    #T_6b745db4_9ae6_11ea_85b8_1c3e84d81555row0_col0 {
#             text-align:  left;
#         }    #T_6b745db4_9ae6_11ea_85b8_1c3e84d81555row0_col1 {
#             text-align:  left;
#         }    #T_6b745db4_9ae6_11ea_85b8_1c3e84d81555row0_col2 {
#             text-align:  left;
#         }    #T_6b745db4_9ae6_11ea_85b8_1c3e84d81555row1_col0 {
#             text-align:  left;
#         }    #T_6b745db4_9ae6_11ea_85b8_1c3e84d81555row1_col1 {
#             text-align:  left;
#         }    #T_6b745db4_9ae6_11ea_85b8_1c3e84d81555row1_col2 {
#             text-align:  left;
#         }    #T_6b745db4_9ae6_11ea_85b8_1c3e84d81555row2_col0 {
#             text-align:  left;
#         }    #T_6b745db4_9ae6_11ea_85b8_1c3e84d81555row2_col1 {
#             text-align:  left;
#         }    #T_6b745db4_9ae6_11ea_85b8_1c3e84d81555row2_col2 {
#             text-align:  left;
# ...

# %% [markdown]
# ##  Retificações

# %%
retificacoes = pd.read_csv('./data/CSVs/retificacoes.csv')
retificacoes_layout = pd.DataFrame(retificacoes).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
retificacoes
hide_toggle()
# Out:
#         <script>
#             function code_toggle_12461936782829187246() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_12461936782829187246()">Toggle show/hide</a>

# %%
retificacoes_layout
# Out:
# <style  type="text/css" >
#     #T_6b7ab510_9ae6_11ea_85b8_1c3e84d81555 th {
#           text-align: left;
#     }    #T_6b7ab510_9ae6_11ea_85b8_1c3e84d81555row0_col0 {
#             text-align:  left;
#         }    #T_6b7ab510_9ae6_11ea_85b8_1c3e84d81555row0_col1 {
#             text-align:  left;
#         }    #T_6b7ab510_9ae6_11ea_85b8_1c3e84d81555row0_col2 {
#             text-align:  left;
#         }    #T_6b7ab510_9ae6_11ea_85b8_1c3e84d81555row1_col0 {
#             text-align:  left;
#         }    #T_6b7ab510_9ae6_11ea_85b8_1c3e84d81555row1_col1 {
#             text-align:  left;
#         }    #T_6b7ab510_9ae6_11ea_85b8_1c3e84d81555row1_col2 {
#             text-align:  left;
#         }    #T_6b7ab510_9ae6_11ea_85b8_1c3e84d81555row2_col0 {
#             text-align:  left;
#         }    #T_6b7ab510_9ae6_11ea_85b8_1c3e84d81555row2_col1 {
#             text-align:  left;
#         }    #T_6b7ab510_9ae6_11ea_85b8_1c3e84d81555row2_col2 {
#             text-align:  left;
# ...

# %% [markdown]
# ## Reversões

# %%
reversao = pd.read_csv('./data/CSVs/reversao.csv')
reversao_layout = pd.DataFrame(reversao).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
reversao
hide_toggle()
# Out:
#         <script>
#             function code_toggle_2531804769919780672() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_2531804769919780672()">Toggle show/hide</a>

# %%
reversao_layout
# Out:
# <style  type="text/css" >
#     #T_6b8699a2_9ae6_11ea_85b8_1c3e84d81555 th {
#           text-align: left;
#     }    #T_6b8699a2_9ae6_11ea_85b8_1c3e84d81555row0_col0 {
#             text-align:  left;
#         }    #T_6b8699a2_9ae6_11ea_85b8_1c3e84d81555row0_col1 {
#             text-align:  left;
#         }    #T_6b8699a2_9ae6_11ea_85b8_1c3e84d81555row0_col2 {
#             text-align:  left;
#         }    #T_6b8699a2_9ae6_11ea_85b8_1c3e84d81555row1_col0 {
#             text-align:  left;
#         }    #T_6b8699a2_9ae6_11ea_85b8_1c3e84d81555row1_col1 {
#             text-align:  left;
#         }    #T_6b8699a2_9ae6_11ea_85b8_1c3e84d81555row1_col2 {
#             text-align:  left;
#         }    #T_6b8699a2_9ae6_11ea_85b8_1c3e84d81555row2_col0 {
#             text-align:  left;
#         }    #T_6b8699a2_9ae6_11ea_85b8_1c3e84d81555row2_col1 {
#             text-align:  left;
#         }    #T_6b8699a2_9ae6_11ea_85b8_1c3e84d81555row2_col2 {
#             text-align:  left;
# ...

# %% [markdown]
# ## Atos sem efeito - Aposentadoria

# %%
atos_sem_efeito_aposentadoria = pd.read_csv('./data/CSVs/atos_sem_efeito_aposentadoria.csv')
atos_sem_efeito_aposentadoria_layout = pd.DataFrame(atos_sem_efeito_aposentadoria).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
atos_sem_efeito_aposentadoria
hide_toggle()
# Out:
#         <script>
#             function code_toggle_10095799990771814956() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_10095799990771814956()">Toggle show/hide</a>

# %%
atos_sem_efeito_aposentadoria_layout
# Out:
# <style  type="text/css" >
#     #T_6b90e0b0_9ae6_11ea_85b8_1c3e84d81555 th {
#           text-align: left;
#     }    #T_6b90e0b0_9ae6_11ea_85b8_1c3e84d81555row0_col0 {
#             text-align:  left;
#         }    #T_6b90e0b0_9ae6_11ea_85b8_1c3e84d81555row0_col1 {
#             text-align:  left;
#         }    #T_6b90e0b0_9ae6_11ea_85b8_1c3e84d81555row0_col2 {
#             text-align:  left;
#         }    #T_6b90e0b0_9ae6_11ea_85b8_1c3e84d81555row1_col0 {
#             text-align:  left;
#         }    #T_6b90e0b0_9ae6_11ea_85b8_1c3e84d81555row1_col1 {
#             text-align:  left;
#         }    #T_6b90e0b0_9ae6_11ea_85b8_1c3e84d81555row1_col2 {
#             text-align:  left;
#         }    #T_6b90e0b0_9ae6_11ea_85b8_1c3e84d81555row2_col0 {
#             text-align:  left;
#         }    #T_6b90e0b0_9ae6_11ea_85b8_1c3e84d81555row2_col1 {
#             text-align:  left;
#         }    #T_6b90e0b0_9ae6_11ea_85b8_1c3e84d81555row2_col2 {
#             text-align:  left;
# ...

# %% [markdown]
# ## Abono de permanência

# %%
abono_de_permanencia = pd.read_csv('./data/CSVs/abono_de_permanencia.csv')
abono_de_permanencia_layout = pd.DataFrame(abono_de_permanencia).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
abono_de_permanencia
hide_toggle()
# Out:
#         <script>
#             function code_toggle_2755980488601226186() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_2755980488601226186()">Toggle show/hide</a>

# %%
abono_de_permanencia_layout
# Out:
# <style  type="text/css" >
#     #T_6b9a035c_9ae6_11ea_85b8_1c3e84d81555 th {
#           text-align: left;
#     }    #T_6b9a035c_9ae6_11ea_85b8_1c3e84d81555row0_col0 {
#             text-align:  left;
#         }    #T_6b9a035c_9ae6_11ea_85b8_1c3e84d81555row0_col1 {
#             text-align:  left;
#         }    #T_6b9a035c_9ae6_11ea_85b8_1c3e84d81555row0_col2 {
#             text-align:  left;
#         }    #T_6b9a035c_9ae6_11ea_85b8_1c3e84d81555row1_col0 {
#             text-align:  left;
#         }    #T_6b9a035c_9ae6_11ea_85b8_1c3e84d81555row1_col1 {
#             text-align:  left;
#         }    #T_6b9a035c_9ae6_11ea_85b8_1c3e84d81555row1_col2 {
#             text-align:  left;
#         }    #T_6b9a035c_9ae6_11ea_85b8_1c3e84d81555row2_col0 {
#             text-align:  left;
#         }    #T_6b9a035c_9ae6_11ea_85b8_1c3e84d81555row2_col1 {
#             text-align:  left;
#         }    #T_6b9a035c_9ae6_11ea_85b8_1c3e84d81555row2_col2 {
#             text-align:  left;
# ...

# %% [markdown]
# ## Retificações - Aposentadoria

# %%
retificacoes_aposentadoria = pd.read_csv('./data/CSVs/retificacoes_aposentadoria.csv')
retificacoes_aposentadoria_layout = pd.DataFrame(retificacoes_aposentadoria).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
retificacoes_aposentadoria
hide_toggle()
# Out:
#         <script>
#             function code_toggle_3590321273630025172() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_3590321273630025172()">Toggle show/hide</a>

# %%
retificacoes_aposentadoria_layout
# Out:
# <style  type="text/css" >
#     #T_6ba5d556_9ae6_11ea_85b8_1c3e84d81555 th {
#           text-align: left;
#     }    #T_6ba5d556_9ae6_11ea_85b8_1c3e84d81555row0_col0 {
#             text-align:  left;
#         }    #T_6ba5d556_9ae6_11ea_85b8_1c3e84d81555row0_col1 {
#             text-align:  left;
#         }    #T_6ba5d556_9ae6_11ea_85b8_1c3e84d81555row0_col2 {
#             text-align:  left;
#         }    #T_6ba5d556_9ae6_11ea_85b8_1c3e84d81555row1_col0 {
#             text-align:  left;
#         }    #T_6ba5d556_9ae6_11ea_85b8_1c3e84d81555row1_col1 {
#             text-align:  left;
#         }    #T_6ba5d556_9ae6_11ea_85b8_1c3e84d81555row1_col2 {
#             text-align:  left;
#         }    #T_6ba5d556_9ae6_11ea_85b8_1c3e84d81555row2_col0 {
#             text-align:  left;
#         }    #T_6ba5d556_9ae6_11ea_85b8_1c3e84d81555row2_col1 {
#             text-align:  left;
#         }    #T_6ba5d556_9ae6_11ea_85b8_1c3e84d81555row2_col2 {
#             text-align:  left;
# ...

# %% [markdown]
# ## Exoneração Cargos Efetivos

# %%
exoneracao_efetivos = pd.read_csv('./data/CSVs/exoneracao_efetivos.csv')
exoneracao_efetivos_layout = pd.DataFrame(exoneracao_efetivos).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
exoneracao_efetivos
hide_toggle()
# Out:
#         <script>
#             function code_toggle_15677674705399127124() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_15677674705399127124()">Toggle show/hide</a>

# %%
exoneracao_efetivos_layout
# Out:
# <style  type="text/css" >
#     #T_6bb07150_9ae6_11ea_85b8_1c3e84d81555 th {
#           text-align: left;
#     }    #T_6bb07150_9ae6_11ea_85b8_1c3e84d81555row0_col0 {
#             text-align:  left;
#         }    #T_6bb07150_9ae6_11ea_85b8_1c3e84d81555row0_col1 {
#             text-align:  left;
#         }    #T_6bb07150_9ae6_11ea_85b8_1c3e84d81555row0_col2 {
#             text-align:  left;
#         }    #T_6bb07150_9ae6_11ea_85b8_1c3e84d81555row1_col0 {
#             text-align:  left;
#         }    #T_6bb07150_9ae6_11ea_85b8_1c3e84d81555row1_col1 {
#             text-align:  left;
#         }    #T_6bb07150_9ae6_11ea_85b8_1c3e84d81555row1_col2 {
#             text-align:  left;
#         }    #T_6bb07150_9ae6_11ea_85b8_1c3e84d81555row2_col0 {
#             text-align:  left;
#         }    #T_6bb07150_9ae6_11ea_85b8_1c3e84d81555row2_col1 {
#             text-align:  left;
#         }    #T_6bb07150_9ae6_11ea_85b8_1c3e84d81555row2_col2 {
#             text-align:  left;
# ...

# %% [markdown]
# ## Substituição de Funções

# %%
substituicao_de_funcao = pd.read_csv('./data/CSVs/substituicao_de_funcao.csv')
substituicao_de_funcao_layout = pd.DataFrame(substituicao_de_funcao).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
substituicao_de_funcao
hide_toggle()
# Out:
#         <script>
#             function code_toggle_4062058000025578662() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_4062058000025578662()">Toggle show/hide</a>

# %%
substituicao_de_funcao_layout
# Out:
# <style  type="text/css" >
#     #T_6bb7b992_9ae6_11ea_85b8_1c3e84d81555 th {
#           text-align: left;
#     }    #T_6bb7b992_9ae6_11ea_85b8_1c3e84d81555row0_col0 {
#             text-align:  left;
#         }    #T_6bb7b992_9ae6_11ea_85b8_1c3e84d81555row0_col1 {
#             text-align:  left;
#         }    #T_6bb7b992_9ae6_11ea_85b8_1c3e84d81555row0_col2 {
#             text-align:  left;
#         }    #T_6bb7b992_9ae6_11ea_85b8_1c3e84d81555row1_col0 {
#             text-align:  left;
#         }    #T_6bb7b992_9ae6_11ea_85b8_1c3e84d81555row1_col1 {
#             text-align:  left;
#         }    #T_6bb7b992_9ae6_11ea_85b8_1c3e84d81555row1_col2 {
#             text-align:  left;
#         }    #T_6bb7b992_9ae6_11ea_85b8_1c3e84d81555row2_col0 {
#             text-align:  left;
#         }    #T_6bb7b992_9ae6_11ea_85b8_1c3e84d81555row2_col1 {
#             text-align:  left;
#         }    #T_6bb7b992_9ae6_11ea_85b8_1c3e84d81555row2_col2 {
#             text-align:  left;
# ...

# %% [markdown]
# ## Cessões

# %%
cessoes = pd.read_csv('./data/CSVs/cessoes.csv')
cessoes_layout = pd.DataFrame(cessoes).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
cessoes
hide_toggle()
# Out:
#         <script>
#             function code_toggle_16840068166043076649() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_16840068166043076649()">Toggle show/hide</a>

# %%
cessoes_layout
# Out:
# <style  type="text/css" >
#     #T_6bc21068_9ae6_11ea_85b8_1c3e84d81555 th {
#           text-align: left;
#     }    #T_6bc21068_9ae6_11ea_85b8_1c3e84d81555row0_col0 {
#             text-align:  left;
#         }    #T_6bc21068_9ae6_11ea_85b8_1c3e84d81555row0_col1 {
#             text-align:  left;
#         }    #T_6bc21068_9ae6_11ea_85b8_1c3e84d81555row0_col2 {
#             text-align:  left;
#         }    #T_6bc21068_9ae6_11ea_85b8_1c3e84d81555row1_col0 {
#             text-align:  left;
#         }    #T_6bc21068_9ae6_11ea_85b8_1c3e84d81555row1_col1 {
#             text-align:  left;
#         }    #T_6bc21068_9ae6_11ea_85b8_1c3e84d81555row1_col2 {
#             text-align:  left;
#         }    #T_6bc21068_9ae6_11ea_85b8_1c3e84d81555row2_col0 {
#             text-align:  left;
#         }    #T_6bc21068_9ae6_11ea_85b8_1c3e84d81555row2_col1 {
#             text-align:  left;
#         }    #T_6bc21068_9ae6_11ea_85b8_1c3e84d81555row2_col2 {
#             text-align:  left;
# ...

# %% [markdown]
# ## Nomeção Cargos Efetivos

# %%
nomeacao_efetivos = pd.read_csv('./data/CSVs/nomeacao_efetivos.csv')
nomeacao_efetivos_layout = pd.DataFrame(nomeacao_efetivos).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
nomeacao_efetivos
hide_toggle()
# Out:
#         <script>
#             function code_toggle_7564566258857189153() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_7564566258857189153()">Toggle show/hide</a>

# %%
nomeacao_efetivos_layout
# Out:
# <style  type="text/css" >
#     #T_6bcc4db2_9ae6_11ea_85b8_1c3e84d81555 th {
#           text-align: left;
#     }    #T_6bcc4db2_9ae6_11ea_85b8_1c3e84d81555row0_col0 {
#             text-align:  left;
#         }    #T_6bcc4db2_9ae6_11ea_85b8_1c3e84d81555row0_col1 {
#             text-align:  left;
#         }    #T_6bcc4db2_9ae6_11ea_85b8_1c3e84d81555row0_col2 {
#             text-align:  left;
#         }    #T_6bcc4db2_9ae6_11ea_85b8_1c3e84d81555row1_col0 {
#             text-align:  left;
#         }    #T_6bcc4db2_9ae6_11ea_85b8_1c3e84d81555row1_col1 {
#             text-align:  left;
#         }    #T_6bcc4db2_9ae6_11ea_85b8_1c3e84d81555row1_col2 {
#             text-align:  left;
#         }    #T_6bcc4db2_9ae6_11ea_85b8_1c3e84d81555row2_col0 {
#             text-align:  left;
#         }    #T_6bcc4db2_9ae6_11ea_85b8_1c3e84d81555row2_col1 {
#             text-align:  left;
#         }    #T_6bcc4db2_9ae6_11ea_85b8_1c3e84d81555row2_col2 {
#             text-align:  left;
# ...

# %% [markdown]
# ## Reposicionamento de Lista de classificação

# %%
reposicionamento = pd.read_csv('./data/CSVs/reposicionamento.csv')
reposicionamento_layout = pd.DataFrame(reposicionamento).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
reposicionamento
hide_toggle()
# Out:
#         <script>
#             function code_toggle_941721903110266754() {
#                 $('div.cell.code_cell.rendered.selected').find('div.input').toggle();
#             }
#
#
#         </script>
#
#         <a href="javascript:code_toggle_941721903110266754()">Toggle show/hide</a>

# %%
reposicionamento_layout
# Out:
# <style  type="text/css" >
#     #T_6bd56dd4_9ae6_11ea_85b8_1c3e84d81555 th {
#           text-align: left;
#     }    #T_6bd56dd4_9ae6_11ea_85b8_1c3e84d81555row0_col0 {
#             text-align:  left;
#         }    #T_6bd56dd4_9ae6_11ea_85b8_1c3e84d81555row0_col1 {
#             text-align:  left;
#         }    #T_6bd56dd4_9ae6_11ea_85b8_1c3e84d81555row0_col2 {
#             text-align:  left;
#         }    #T_6bd56dd4_9ae6_11ea_85b8_1c3e84d81555row1_col0 {
#             text-align:  left;
#         }    #T_6bd56dd4_9ae6_11ea_85b8_1c3e84d81555row1_col1 {
#             text-align:  left;
#         }    #T_6bd56dd4_9ae6_11ea_85b8_1c3e84d81555row1_col2 {
#             text-align:  left;
#         }    #T_6bd56dd4_9ae6_11ea_85b8_1c3e84d81555row2_col0 {
#             text-align:  left;
#         }    #T_6bd56dd4_9ae6_11ea_85b8_1c3e84d81555row2_col1 {
#             text-align:  left;
#         }    #T_6bd56dd4_9ae6_11ea_85b8_1c3e84d81555row2_col2 {
#             text-align:  left;
# ...

# %% [markdown]
# ## Tabela com repetições

# %%
tables_array = [aposentadoria, exoneracao, nomeacao_comissionados, atos_sem_efeito, retificacoes, reversao,
                atos_sem_efeito_aposentadoria, abono_de_permanencia, retificacoes_aposentadoria,
                exoneracao_efetivos, substituicao_de_funcao, cessoes, nomeacao_efetivos, reposicionamento]
table_with_repetitions = pd.concat(tables_array, ignore_index=True)

# %% [markdown]
# ## Tabela sem repetições

# %%
# Table with duplicates dropped
table_without_duplicates = table_with_repetitions.drop_duplicates(subset="Atributo", 
                                                                  keep="first", 
                                                                  ignore_index=True)

# %% [markdown]
# ## Gráfico Obrigatoriedade

# %%
# Tuple with key and value (Obrigatoriedade, Repetições)
madatory_repetitions = table_with_repetitions["Obrigatoriedade"].value_counts()
madatory_repetitions
# Out:
# Obrigatório        92
# Não Obrigatório    88
# Name: Obrigatoriedade, dtype: int64

# %%
labels = ["Obrigatório", "Não Obrigatório"]
sizes = [madatory_repetitions[0], madatory_repetitions[1]]
colors = ['#86BA90', '#F5F3BB']
fig1, ax1 = plt.subplots(figsize=(8,8))
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90, colors=colors)
ax1.axis("equal")
ax1.set_title("Taxa de obrigatoriedade dos atributos")
ax1.legend(labels, title='Obrigatoriedade', 
           loc='center left', 
           bbox_to_anchor=(1.3, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ## Gráfico Repetição de Atributos

# %%
# Tuple with key and value (Atributo, Repetições)
repeted_attributes = table_with_repetitions["Atributo"].value_counts()
repeted_attributes
# Out:
# Matrícula                                                  10
# Nome do Servidor                                           10
# Cargo Efetivo                                              10
# Processo GDF/SEI                                            8
# Classe                                                      7
# Órgão                                                       7
# Padrão                                                      7
# Vigência                                                    7
# Fundamento Legal                                            6
# Matricula SIAPE                                             6
# Matrícula SIAPE                                             5
# Quadro pessoal permanente ou Suplementar                    5
# Tipo de documento                                           4
# Número do DODF                                              4
# Orgão                                                       4
# ...

# %%
figure(num=None, figsize=(21, 9), dpi=80, facecolor='w', edgecolor='k')

labels = []
sizes = []
count = 0
keys = repeted_attributes.keys()


for i in range(0, len(list(repeted_attributes))):
    if repeted_attributes[i] > 1:
        sizes.append(repeted_attributes[i])
        count += 1

for j in range(0, count):
    labels.append(keys[j])
    
    
def plt_bar():
    index = np.arange(len(labels))
    plt.barh(index, sizes)
    plt.xlabel('N° de repetições', fontsize=8)
    plt.ylabel('Atributos', fontsize=8)
    plt.yticks(index, labels, fontsize=8, rotation=0)
    plt.title('Repetição de Atributos')
    plt.show()
    
plt_bar()

# %% [markdown]
# ## Gráfico porcentagem de repetição de atributos

# %%
# Quantidade de atributos diferentes que existem
total_attributes = len(repeted_attributes)

# Quantidade de atributos que se repetem
total_repeted = len(sizes)

print(f'Total de atributos diferentes: {total_attributes}')
print(f'Total de atributos que aparecem mais de uma vez:  {total_repeted}')
# Out:
# Total de atributos diferentes: 59
# Total de atributos que aparecem mais de uma vez:  39

# %%
labels = ["Se repetem", "Não se repetem"]
sizes = [total_repeted, total_attributes - total_repeted]
colors = ['#60606F', '#A5A475']
fig1, ax1 = plt.subplots(figsize=(8,8))
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90, colors=colors)
ax1.axis("equal")
ax1.set_title("Taxa de obrigatoriedade dos atributos")
ax1.legend(labels, title='Obrigatoriedade', 
           loc='center left', 
           bbox_to_anchor=(1.3, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ## Gráfico porcentagem que possui padrão

# %%
# Tuple with key and value (Padrão, Repetições)
pattern = table_with_repetitions["Padrão"].value_counts()
pattern
# Out:
# Sem Padrão                                       47
# Letras maiúsculas                                12
# Após 'matrícula n°'                              11
# Após Classe                                       7
# Após cargo                                        7
# SIAPE                                             6
# Começa com 'nos termos do'                        6
# Após 'a contar de'                                6
# Após padrão, começa com 'do Quadro'               5
# Após 'Símbolo'                                    5
# Após 'SIAPE'                                      5
# Após 'página'                                     4
# Após 'n°'                                         4
# Começa com 'Processo SEI'                         4
# Após Hierarquia da Lotação                        3
# Após Cargo em Comissão                            3
# Após Simbolo                                      3
# Após 'LEIA-SE'                                    2
# ...

# %%
total_rows_table_with_repetitions = madatory_repetitions[0] + madatory_repetitions[1]
total_rows_table_with_repetitions
# Out:
# 180

# %%
labels = ["Com padrão", "Sem padrão"]
sizes = [total_rows_table_with_repetitions - pattern[0], pattern[0]]
colors = ['#9B9987', '#685762']
fig1, ax1 = plt.subplots(figsize=(8,8))
ax1.pie(sizes, labels=labels, autopct='%1.1f%%', shadow=True, startangle=90, colors=colors)
ax1.axis("equal")
ax1.set_title("Taxa de obrigatoriedade dos atributos")
ax1.legend(labels, title='Obrigatoriedade', 
           loc='center left', 
           bbox_to_anchor=(1.3, 0, 0.5, 1))
plt.show()

# %% [markdown]
# ## Tabela Obrigatórios e com padrão

# %%
obrigatorios_e_com_padrão = table_with_repetitions.loc[((table_with_repetitions["Obrigatoriedade"] == "Obrigatório") 
                                                       & (table_with_repetitions["Padrão"] != "Sem Padrão"))]
obrigatorios_e_com_padrão = obrigatorios_e_com_padrão.drop_duplicates(subset="Atributo", 
                                                                  keep="first", 
                                                                  ignore_index=True)

obrigatorios_e_com_padrão = pd.DataFrame(obrigatorios_e_com_padrão).style.set_properties(**{'text-align': 'left'}).set_table_styles([ dict(selector='th', props=[('text-align','left')] ) ])
obrigatorios_e_com_padrão
# Out:
# <style  type="text/css" >
#     #T_6ca4e398_9ae6_11ea_85b8_1c3e84d81555 th {
#           text-align: left;
#     }    #T_6ca4e398_9ae6_11ea_85b8_1c3e84d81555row0_col0 {
#             text-align:  left;
#         }    #T_6ca4e398_9ae6_11ea_85b8_1c3e84d81555row0_col1 {
#             text-align:  left;
#         }    #T_6ca4e398_9ae6_11ea_85b8_1c3e84d81555row0_col2 {
#             text-align:  left;
#         }    #T_6ca4e398_9ae6_11ea_85b8_1c3e84d81555row1_col0 {
#             text-align:  left;
#         }    #T_6ca4e398_9ae6_11ea_85b8_1c3e84d81555row1_col1 {
#             text-align:  left;
#         }    #T_6ca4e398_9ae6_11ea_85b8_1c3e84d81555row1_col2 {
#             text-align:  left;
#         }    #T_6ca4e398_9ae6_11ea_85b8_1c3e84d81555row2_col0 {
#             text-align:  left;
#         }    #T_6ca4e398_9ae6_11ea_85b8_1c3e84d81555row2_col1 {
#             text-align:  left;
#         }    #T_6ca4e398_9ae6_11ea_85b8_1c3e84d81555row2_col2 {
#             text-align:  left;
# ...
